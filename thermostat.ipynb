# %% [markdown]
# ## Thermostat
#
# `Author`: Preston Robinette
#
# `Updated`: 12.16.24

# %%
import matplotlib.pyplot as plt
import utils

# %% [markdown]
# ### Generate fake data

# %%
fake_data = utils.generate_mock_data(num_customers=30)

fake_data.head()
# Out:
#    pivot_date  customer_id approved_at  days_delinquent  \
# 0  2024-12-16            1   2024-2-20                0
# 1  2024-12-16            2  2024-12-25                0
# 2  2024-12-16            3  2024-11-17                0
# 3  2024-12-16            4    2024-4-9                0
# 4  2024-12-16            5   2024-12-9               73
#
#    monthly_recurr_revenue  device_value
# 0                   66.67           800
# 1                  250.00          3000
# 2                   66.67           800
# 3                   66.67           800
# 4                  100.00          1200

# %% [markdown]
# ### Process results
#
# Calculate the cost to Fragile.
# > Cost = (days_delinquent//30) * monthly_recurr_revenue
#
# The impact is then calculated based on the length of delinquency:
# > `green (no impact)`: (days_delinquent//30) == 0
#
# > `yellow (medium impact)`: 0 < (days_delinquent//30) <= 3
#
# > `red (high impact)`: (days_delinquent//30) > 3
#
#
# The threshold between yellow and red can be updated with the threshold var below.

# %%
process_data = utils.eval_data(fake_data, threshold=2)

# %% [markdown]
# ### Create plots of customer impact

# %%
fig_pie = utils.generate_pie_chart(process_data)

plt.show()

# %%
fig, ax = utils.generate_plot(process_data)

plt.show()
